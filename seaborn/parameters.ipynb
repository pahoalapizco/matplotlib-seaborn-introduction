# %% [markdown]
# # Parametros más comunes al usar seaborn

# %% [markdown]
# Seaborn cuenta con una gran variedad de graficos para distintos propositos, y cada uno de ellos cuenta con una serie de parámetos que nos ayudan a representar la información de mejor manera.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Con `load_dataset` cargamos un dataset de exemplo del [repositorio de data](https://github.com/mwaskom/seaborn-data) propio de seaborn, para ello es necesario una conexión a internet.

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# En este ejemplo se utiliza el tipo de grafica `displot` que nos va a mostrar un histograma con la frecuencia de los datos, donde:
# - **data**: tips
# - **x**: total_bill

# %%
sns.displot(data=tips, x='total_bill')
plt.show()

# %% [markdown]
# Agregamos el parámetro `y`, donde
# - **y**: tips
#
# Seaborn detecta que el grafico de frecuencias no es la mejor opción y lo adapta a una grafica de disitribución que muestra la relación entre ambos ejes

# %%
sns.displot(data=tips, x='total_bill', y='tip')
plt.show()

# %% [markdown]
# Con el parámetro `hue` le indicamos como segmentar los datos.
# - **hue**: sex

# %%
sns.displot(data=tips, x='total_bill', y='tip', hue='sex')
plt.show()

# %% [markdown]
# `hue` también funciona si la grafica es un histograma

# %%
sns.displot(data=tips, x='total_bill', hue='sex')
plt.show()

# %% [markdown]
# `kind` es una propieda con la cual le podemos indicar a la función `displot` como representar la grafica.
#
# - **kind**: kde, muestra un grafico de densidad

# %%
sns.displot(data=tips, x='total_bill', hue='sex', kind='kde')
plt.show()

# %% [markdown]
# Con `palette` cambiammos la paleta de colores en el grafico.

# %%
sns.displot(data=tips, x='total_bill', hue='sex', kind='kde', palette='Spectral')
plt.show()

# %% [markdown]
# Con `alpha` cambiamos la opacidad del grafico

# %%
sns.displot(data=tips, x='total_bill', hue='sex', kind='kde', palette='Spectral', alpha=0.35)
plt.show()

# %% [markdown]
# [Documentación de displot](https://seaborn.pydata.org/generated/seaborn.displot.html)
